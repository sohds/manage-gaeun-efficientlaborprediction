# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# jupyter notebook 내 그래프를 바로 그리기 위한 설정
# %matplotlib inline

# unicode minus를 사용하지 않기 위한 설정 (minus 깨짐현상 방지)
plt.rcParams['axes.unicode_minus'] = False

df = pd.read_excel("2203_2210days_excel_copy.xlsx")
sns.set_style('whitegrid')
sns.set_context("poster")
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.figure(figsize=(24, 12))
sns.scatterplot(data = df, x = '판매일자', y = '판매 총액', hue='요일', ## 각 요일별로 색상이 다르게 그려진다.
                hue_order = ['월', '화', '수', '목', '금'], ## 월, 화, 수, 목, 금 순으로 색상과 범례가 표시
                s=150
               )
# Out:
# <AxesSubplot:xlabel='판매일자', ylabel='판매 총액'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 161 entries, 0 to 160
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   판매일자    161 non-null    datetime64[ns]
#  1   요일      161 non-null    object
#  2   판매 총액   161 non-null    int64
#  3   결제 금액   161 non-null    int64
#  4   첫주문시간   161 non-null    datetime64[ns]
#  5   최종주문시간  161 non-null    datetime64[ns]
#  6   주문횟수    161 non-null    int64
#  7   개점시간    161 non-null    datetime64[ns]
#  8   폐점시간    161 non-null    datetime64[ns]
# dtypes: datetime64[ns](5), int64(3), object(1)
# memory usage: 11.4+ KB
